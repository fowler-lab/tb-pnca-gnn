# %% [markdown]
# # Bootstrapping Evaluation

# %%
import sys
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
import torch
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.patches import Patch, Rectangle
import seaborn as sns
from torch_geometric.data import DataLoader

path = os.path.join('..', '.')
if path not in sys.path:
    sys.path.append(os.path.abspath(path))

from src import evaluation, model_helpers

import pickle as pkl

# %% [markdown]
# ### Reproduce bootstrapping from Carter et al
#
# Same sampling method - each of the 10 samples is the same as in Carter et al
#
# - Get mutations/indexes of ds-test.npy for the samples
# - Use the same sample for the bootstraps for evaluation

# %%
from sklearn.utils import resample

from statsmodels.stats.weightstats import ztest as ztest

# %%
# Select model and dataset
model_choices = {
    "base": "../saved_models/full_model/F1=0.816_epoch=1119.pth",
    "cluster": "../saved_models/cluster-split/F1=0.798_epoch=248.pth",
    "codon": "../saved_models/codon-split/F1=0.835_epoch=246.pth"
}
dataset_choices = {
    "base": "./datasets/x18_exp_l2_graph_dict.pkl",
    "cluster": "./datasets/clustered_2_graph_dict.pkl",
    "codon": "./datasets/codon_graph_dict.pkl"
}
input_choices = {
    "base": "../data/inputs/ds-{}{}.npy",
    "cluster": "../data/inputs/clustered-ds-{}{}.npy",
    "codon": "../data/inputs/codon-ds-{}{}.npy"
}

split = "base"  # "base", "codon", "cluster"

model_path = model_choices[split]
dataset_path = dataset_choices[split]
input_path = input_choices[split]

# %%
# Load the training dataset
X, Y, Z = {}, {}, {}
for split_type in ['train', 'test']:
    X[split_type], Y[split_type], Z[split_type] = {}, {}, {}
    with open(input_path.format(split_type, ""), 'rb') as f:
        Y[split_type]['input'] = np.load(f)
        X[split_type]['input'] = np.load(f)
        Z[split_type]['input'] = np.load(f, allow_pickle=True)

# %%
number_of_bootstraps = 10

def bootstrap_model(features, labels, mutations):
    x={}
    y={}
    z = {}
    for i in range(number_of_bootstraps):
        x[i],y[i], z[i] = resample(features['test']['input'], labels['test']['input'], mutations['test']['input'], random_state=42+i)

    return x, y, z

# %%
x, y, z = bootstrap_model(X, Y, Z)
z
# Out:
# {0: array(['V128G', 'A46S', 'I52N', 'H57Q', 'H43Y', 'G17S', 'F58Y', 'A30P',
#         'V128G', 'R176G', 'N11I', 'S88T', 'S59T', 'A46E', 'H82L', 'G108R',
#         'Q122L', 'R123C', 'A20E', 'G78D', 'S88T', 'D86N', 'M175I', 'E144G',
#         'D49G', 'I90S', 'A30P', 'R29C', 'D110N', 'L116P', 'Q10H', 'F13V',
#         'A178D', 'G97D', 'I90S', 'H57Q', 'Q141E', 'Q141E', 'A38S', 'Q141E',
#         'D129E', 'Q10P', 'A20S', 'V45L', 'Q122L', 'D129E', 'V139L', 'A30P',
#         'A79S', 'L4F', 'P54T', 'H71D', 'Q10H', 'G75D', 'K48T', 'L172R',
#         'E173K', 'A20E', 'E144G', 'G16S', 'A3V', 'G60D', 'I90S', 'A20T',
#         'A143D', 'E127K', 'A38S', 'A36V', 'R123L', 'H57P', 'I90F', 'H82L',
#         'H71D', 'G78D', 'I6F', 'C184Y', 'A79T', 'P62L', 'C184Y', 'E107Q',
#         'G124A', 'D49E', 'I31N', 'Q141E', 'K48T', 'L182W', 'S32I', 'H57Q',
#         'V7D', 'Q141E', 'L182M', 'Y103D', 'G60D', 'A20E', 'D110V', 'T168A',
#         'I90S', 'V163M', 'V157A', 'N112Y', 'H57Q', 'Y95N', 'F50Y', 'Q10H',
#         'D8G', 'L172R', 'S88T', 'M175L', 'N149K', 'M1V', 'A39S', 'R123L',
#         'N149K', 'V163G', 'V163G', 'V183I', 'W68L', 'L120R', 'V157A',
#         'S67P', 'V139L', 'G17S', 'W119G', 'I31N', 'V183I', 'S32I', 'A92S',
#         'S32R', 'S18P', 'T160I', 'A143D', 'H82L', 'A36V', 'G124C', 'G23A',
#         'A38S', 'Q122L', 'T76S', 'L120R', 'V93L', 'V128G', 'V139E',
#         'E127D', 'H57Q', 'E173K', 'C138S', 'V163M', 'S18T', 'M1V', 'R140P',
#         'I133N', 'R140P', 'H71D', 'A92S', 'D86E', 'G132R', 'F94C', 'A28P',
#         'K96T', 'G105S', 'D8G', 'D63N', 'D12E', 'S67P', 'S185G', 'G97D',
#         'Y95N', 'S32R', 'W119R', 'I6F', 'S67P', 'S67P', 'Q10P', 'D49E',
#         'G16S', 'L19V', 'Q141E', 'N11I', 'V169F', 'A3V', 'Q141E', 'M175L',
#         'F81S', 'V139E', 'Q141E', 'F81S', 'L35R', 'V130E', 'V128G',
#         'G124D', 'V7D', 'E174G', 'E127D', 'S32R', 'E181K', 'D129E',
#         'A143D', 'G108R', 'A178D', 'W68G'], dtype=object),
#  1: array(['E15D', 'F50Y', 'I90F', 'L116P', 'A178D', 'F13I', 'I133N', 'G124A',
#         'I90S', 'A3V', 'T22A', 'G60D', 'H71P', 'S88T', 'F50Y', 'A28P',
#         'V169F', 'S18T', 'V163M', 'E173K', 'N112S', 'F13Y', 'A36V', 'G17V',
#         'T22A', 'W68G', 'H57R', 'S18P', 'W68G', 'N118Y', 'V183I', 'V45A',
#         'T100A', 'V163E', 'V163G', 'F13V', 'L156P', 'A143V', 'F81S',
#         'F94C', 'V163E', 'N149K', 'S32R', 'L116R', 'S32I', 'L172Q',
#         'L159Q', 'R29C', 'P62L', 'V163G', 'G97D', 'T168A', 'D86N', 'V7F',
#         'E174G', 'L159Q', 'L116P', 'N11I', 'S67P', 'D63N', 'E127K', 'S32R',
#         'A46E', 'V7F', 'I133N', 'V163G', 'A38S', 'H43Y', 'A20E', 'V131D',
#         'D110V', 'H71D', 'V163M', 'D8G', 'L172P', 'I133N', 'V180G', 'H71N',
#         'T142R', 'S88T', 'S18P', 'D12E', 'H57Q', 'G16S', 'D12E', 'V157A',
#         'V21L', 'S67P', 'D8H', 'I90F', 'A20T', 'H82R', 'F13I', 'M175K',
#         'V45L', 'H71N', 'N112Y', 'I90S', 'N149D', 'I31N', 'Y99D', 'K48T',
#         'L172R', 'G124C', 'I133N', 'G16V', 'V163E', 'L120R', 'A38S', 'D8G',
#         'M175K', 'A143D', 'S88T', 'I90T', 'D12E', 'L172P', 'N112Y',
#         'G108R', 'E181K', 'A3V', 'F58I', 'I90T', 'D110V', 'T135P', 'V163M',
#         'W68G', 'M175K', 'Q122L', 'S84R', 'S67P', 'D56N', 'L4F', 'L172Q',
#         'T135P', 'Y103D', 'H43Y', 'L116R', 'V163M', 'E144G', 'D129E',
#         'M175L', 'V180G', 'E15D', 'M175I', 'S18T', 'V139E', 'E107Q',
#         'G78D', 'V45A', 'G75V', 'E15Q', 'P54T', 'A143V', 'G124C', 'G97V',
#         'S18T', 'G124A', 'V45L', 'Y95C'], dtype=object),
#  3: array(['H71P', 'H71D', 'A30S', 'V183I', 'R140P', 'Q141E', 'H57P', 'E15D',
#         'R176G', 'F81S', 'E15Q', 'S185G', 'D86E', 'C184Y', 'D110N', 'V7F',
#         'D166V', 'L172R', 'L159Q', 'D8E', 'V163G', 'A30S', 'L172P', 'K96T',
#         'P54T', 'A143V', 'G60D', 'V21L', 'H71P', 'G97V', 'H57Q', 'S18P',
#         'N149D', 'Y41H', 'E181K', 'A146E', 'Q141E', 'G124A', 'V180G',
#         'M175K', 'D8H', 'W119G', 'E127D', 'I90F', 'D49Y', 'V163M', 'V45L',
#         'D8H', 'A20S', 'H82R', 'Y95C', 'F13Y', 'R140P', 'V45L', 'T160I',
#         'D80N', 'H82L', 'S67P', 'V183I', 'H82R', 'D63N', 'V45A', 'A79T',
#         'A20S', 'R176G', 'A20T', 'R29C', 'H82R', 'G75D', 'I52N', 'V169F',
#         'R176S', 'Q10H', 'Y99D', 'Y103D', 'P115A', 'R176S', 'V45A',
#         'A146E', 'S67P', 'F58I', 'S88T', 'L4W', 'A30P', 'G24D', 'G24D',
#         'H137Q', 'A146E', 'H43Y', 'S18T', 'E127K', 'D110N', 'E173V',
#         'E15D', 'D110V', 'G17V', 'V169F', 'A30S', 'G97D', 'G23V', 'D8G',
#         'V130E', 'G17S', 'A20T', 'S67P', 'N118Y', 'G16V', 'S185I', 'D158N',
#         'V139L', 'F13V', 'D86E', 'V45A', 'R176S', 'A20E', 'I133N', 'R148L',
#         'D8H', 'N149K', 'D158N', 'R123C', 'D12E', 'L4W', 'H57Q', 'E144G',
#         'F13V', 'N149I', 'Q10P', 'H137Q', 'A89P', 'H71P', 'D49E', 'G24D',
#         'M175K', 'A30S', 'K96Q', 'H43P', 'Y41H', 'I133N', 'V163M', 'G60D',
#         'G16V', 'R176G', 'H82L', 'F13I', 'G132R', 'V73L', 'I90F', 'F58Y',
#         'Y103D', 'E15D', 'K96Q', 'A36V', 'W119G', 'G75V', 'T160I', 'I90S',
#         'M175I', 'D158N', 'G16V', 'N149H', 'N149D', 'L182W', 'D8E',
#         'E173V', 'W119R', 'L19V', 'V7D', 'A178D', 'N149D', 'V163G', 'K96T',
#         'L182M', 'C138S', 'V139L', 'I52N', 'A143V', 'Q10P', 'A30D', 'W68G',
#         'Q141E', 'E181K', 'R148L', 'A178D', 'S18P', 'N112S', 'V7D', 'W68G',
#         'D49E', 'F58L', 'F94C', 'F50Y', 'A20S', 'L116P', 'R140P', 'A178D',
#         'I52N', 'D49E', 'N11I', 'H57Q'], dtype=object),
#  4: array(['Q141E', 'L35V', 'V157A', 'S59T', 'D63N', 'D158N', 'V131D',
with open(dataset_path, 'rb') as f:
    data = pkl.load(f)

mut_map = {}

for k, v in data['test'].items():
    key = k
    value = v['metadata']['mutation'].values[0]
    mut_map[value] = key

mut_map
# Out:
# {'I90T': 'pnca_mut_99',
#  'A161T': 'pnca_mut_3',
#  'V7F': 'pnca_mut_188',
#  'A39S': 'pnca_mut_15',
#  'R123G': 'pnca_mut_142',
#  'D86N': 'pnca_mut_38',
#  'S104I': 'pnca_mut_150',
#  'L116R': 'pnca_mut_104',
#  'E91D': 'pnca_mut_53',
#  'D8H': 'pnca_mut_41',
#  'L35V': 'pnca_mut_116',
#  'N149D': 'pnca_mut_129',
#  'Y95N': 'pnca_mut_197',
#  'V45L': 'pnca_mut_185',
#  'H57Q': 'pnca_mut_86',
#  'I31N': 'pnca_mut_94',
#  'F81S': 'pnca_mut_61',
#  'Q10H': 'pnca_mut_136',
#  'L172Q': 'pnca_mut_109',
#  'N112S': 'pnca_mut_124',
#  'G23A': 'pnca_mut_73',
#  'A46S': 'pnca_mut_18',
#  'D49Y': 'pnca_mut_33',
#  'V128G': 'pnca_mut_170',
#  'D129E': 'pnca_mut_27',
#  'D63N': 'pnca_mut_35',
#  'T100A': 'pnca_mut_162',
#  'A36V': 'pnca_mut_13',
#  'R123L': 'pnca_mut_144',
#  'T76S': 'pnca_mut_169',
#  'S32R': 'pnca_mut_156',
#  'K96T': 'pnca_mut_102',
#  'F13V': 'pnca_mut_55',
#  'E15G': 'pnca_mut_47',
#  'L172R': 'pnca_mut_110',
#  'G75V': 'pnca_mut_78',
#  'A20E': 'pnca_mut_5',
#  'G124D': 'pnca_mut_67',
#  'N149H': 'pnca_mut_130',
#  'F58I': 'pnca_mut_58',
#  'M175L': 'pnca_mut_122',
#  'G24D': 'pnca_mut_75',
#  'R29C': 'pnca_mut_149',
#  'V163E': 'pnca_mut_176',
#  'A89P': 'pnca_mut_21',
#  'T142R': 'pnca_mut_164',
#  'W119R': 'pnca_mut_191',
#  'A28P': 'pnca_mut_8',
#  'V21L': 'pnca_mut_183',
#  'G97D': 'pnca_mut_80',
#  'H82R': 'pnca_mut_92',
#  'A146E': 'pnca_mut_2',
#  'V93L': 'pnca_mut_189',
#  'I90S': 'pnca_mut_98',
#  'E181K': 'pnca_mut_52',
#  'L120R': 'pnca_mut_105',
#  'G132R': 'pnca_mut_68',
#  'L4F': 'pnca_mut_117',
#  'D8G': 'pnca_mut_40',
#  'N11I': 'pnca_mut_128',
#  'R123H': 'pnca_mut_143',
#  'A38S': 'pnca_mut_14',
#  'D8E': 'pnca_mut_39',
#  'S185G': 'pnca_mut_151',
#  'H57R': 'pnca_mut_87',
#  'I52N': 'pnca_mut_95',
#  'Y95C': 'pnca_mut_196',
#  'V45A': 'pnca_mut_184',
#  'A79S': 'pnca_mut_19',
#  'D110V': 'pnca_mut_26',
#  'V130E': 'pnca_mut_171',
#  'T135P': 'pnca_mut_163',
#  'D56N': 'pnca_mut_34',
#  'Q10P': 'pnca_mut_137',
#  'F58Y': 'pnca_mut_60',
#  'G17V': 'pnca_mut_72',
#  'N112Y': 'pnca_mut_125',
#  'F13I': 'pnca_mut_54',
#  'L116P': 'pnca_mut_103',
#  'L182M': 'pnca_mut_111',
#  'E15D': 'pnca_mut_46',
#  'G78D': 'pnca_mut_79',
#  'R140P': 'pnca_mut_145',
#  'A36S': 'pnca_mut_12',
#  'T22A': 'pnca_mut_168',
#  'S59T': 'pnca_mut_157',
#  'A178D': 'pnca_mut_4',
#  'D49G': 'pnca_mut_32',
#  'R176S': 'pnca_mut_148',
#  'A79T': 'pnca_mut_20',
#  'V163G': 'pnca_mut_177',
#  'T160I': 'pnca_mut_165',
#  'N149I': 'pnca_mut_131',
#  'G124C': 'pnca_mut_66',
#  'F58L': 'pnca_mut_59',
#  'G23V': 'pnca_mut_74',
#  'M1V': 'pnca_mut_123',
#  'G97V': 'pnca_mut_81',
#  'I133N': 'pnca_mut_93',
#  'W119G': 'pnca_mut_190',
#  'A30D': 'pnca_mut_9',
#  'V21G': 'pnca_mut_182',
#  'A46E': 'pnca_mut_17',
#  'Q141E': 'pnca_mut_140',
#  'D12E': 'pnca_mut_28',
#  'S185I': 'pnca_mut_152',
#  'Q122L': 'pnca_mut_139',
#  'L156P': 'pnca_mut_106',
#  'E174G': 'pnca_mut_51',
#  'E127D': 'pnca_mut_43',
#  'L35Q': 'pnca_mut_114',
#  'H71N': 'pnca_mut_89',
#  'Y99D': 'pnca_mut_198',
#  'A143V': 'pnca_mut_1',
#  'G105S': 'pnca_mut_63',
#  'P54T': 'pnca_mut_134',
#  'L4W': 'pnca_mut_119',
#  'N118Y': 'pnca_mut_126',
#  'G17S': 'pnca_mut_71',
#  'V131D': 'pnca_mut_172',
#  'D110N': 'pnca_mut_25',
#  'D86E': 'pnca_mut_37',
#  'S88P': 'pnca_mut_160',
#  'Y41H': 'pnca_mut_195',
#  'V7D': 'pnca_mut_187',
#  'H43Y': 'pnca_mut_84',
#  'I6F': 'pnca_mut_96',
#  'A20T': 'pnca_mut_7',
#  'A30S': 'pnca_mut_11',
#  'R148L': 'pnca_mut_146',
#  'V169F': 'pnca_mut_179',
#  'S18T': 'pnca_mut_154',
#  'K48T': 'pnca_mut_100',
#  'F50Y': 'pnca_mut_57',
#  'E144G': 'pnca_mut_45',
#  'L182W': 'pnca_mut_112',
#  'W68L': 'pnca_mut_193',
#  'V183I': 'pnca_mut_181',
#  'H137Q': 'pnca_mut_82',
#  'H71P': 'pnca_mut_90',
#  'L172P': 'pnca_mut_108',
#  'G124A': 'pnca_mut_65',
#  'N149K': 'pnca_mut_132',
#  'E15Q': 'pnca_mut_48',
#  'M175I': 'pnca_mut_120',
#  'G75D': 'pnca_mut_77',
#  'V139L': 'pnca_mut_174',
#  'C138S': 'pnca_mut_23',
#  'D49E': 'pnca_mut_31',
#  'T168A': 'pnca_mut_166',
#  'S84R': 'pnca_mut_159',
#  'Q10R': 'pnca_mut_138',
#  'L35R': 'pnca_mut_115',
#  'E173V': 'pnca_mut_50',
#  'L159Q': 'pnca_mut_107',
#  'E107Q': 'pnca_mut_42',
#  'R123C': 'pnca_mut_141',
#  'A3V': 'pnca_mut_16',
#  'D158N': 'pnca_mut_29',
#  'S18P': 'pnca_mut_153',
#  'Y99F': 'pnca_mut_199',
#  'A143D': 'pnca_mut_0',
#  'H71D': 'pnca_mut_88',
#  'C184Y': 'pnca_mut_24',
#  'V139E': 'pnca_mut_173',
#  'S88T': 'pnca_mut_161',
#  'D80N': 'pnca_mut_36',
#  'P62L': 'pnca_mut_135',
#  'F94C': 'pnca_mut_62',
#  'L4V': 'pnca_mut_118',
#  'G16V': 'pnca_mut_70',
#  'N11H': 'pnca_mut_127',
#  'H57P': 'pnca_mut_85',
#  'I90F': 'pnca_mut_97',
#  'Y103D': 'pnca_mut_194',
#  'V73L': 'pnca_mut_186',
#  'A20S': 'pnca_mut_6',
#  'G16S': 'pnca_mut_69',
#  'F13Y': 'pnca_mut_56',
#  'K96Q': 'pnca_mut_101',
#  'L19V': 'pnca_mut_113',
#  'E127K': 'pnca_mut_44',
#  'R176G': 'pnca_mut_147',
#  'A30P': 'pnca_mut_10',
#  'V163M': 'pnca_mut_178',
#  'S32I': 'pnca_mut_155',
#  'H43P': 'pnca_mut_83',
#  'H82L': 'pnca_mut_91',
#  'W68G': 'pnca_mut_192',
#  'V180G': 'pnca_mut_180',
#  'A92S': 'pnca_mut_22',
#  'V157A': 'pnca_mut_175',
#  'T177I': 'pnca_mut_167',
#  'D166V': 'pnca_mut_30',
#  'S67P': 'pnca_mut_158',
#  'P115A': 'pnca_mut_133',
#  'G108R': 'pnca_mut_64',
#  'E173K': 'pnca_mut_49',
#  'G60D': 'pnca_mut_76',
#  'M175K': 'pnca_mut_121'}

# %% [markdown]
# ### Evaluate GCN (and control models) with bootstrapped sampling

# %%
def evaluate_bootstrap_model(model, data_loaders, show_roc=False):
    sens = []
    spec = []
    roc_auc = []
    f1 = []
    for b in data_loaders:
        print(f"Bootstrap {b}:")

        fpr, tpr, roc_auc_res = evaluation.calculate_roc(model, data_loaders[b])
        if show_roc:
            evaluation.plot_roc_curve(fpr, tpr, roc_auc)
        sens_res,spec_res,f1_res, cm_res = evaluation.calculate_metrics(model, data_loaders[b])
        sens.append(sens_res)
        spec.append(spec_res)
        f1.append(f1_res)
        roc_auc.append(roc_auc_res)

        print("\n --- \n")
        
    return {"sensitivity": sens, "specificity": spec, "f1": f1, "roc_auc": roc_auc, "confusion_matrix": cm_res}

# %%
def bootstrap_loop(model,
                   dataset, 
                   remove_mpfs=False,
                   remove_sbmlcore=False,
                   shuffle_edges=False,
                   remove_ews=False
                   ):

    with open(dataset, 'rb') as f:
        
        data = pkl.load(f)
    
    if any([remove_mpfs, remove_sbmlcore, shuffle_edges]):
        # edit dataset for control experiments
        model_helpers.redefine_graph(data,
                                    cutoff_distance=12,
                                    edge_weight_func='exp',
                                    lambda_param=2.0,
                                    normalise_ews=True,
                                    no_node_mpfs=remove_mpfs,
                                    no_node_chem_feats=remove_sbmlcore,
                                    shuffle_edges=shuffle_edges)

    if remove_ews:
        for split in data:
            for sample in data[split]:
                data[split][sample]['graph'].dataset[0]['edge_attr'] = None
    
    bootstrapped_data = {}
    
    # create bootstrapped data
    for i in z:
        bootstrapped_data[i] = []
        for sample in z[i]:
            dict_sample = mut_map[sample]
            bootstrapped_data[i].append(data['test'][dict_sample])
            
    # check bootstrapping matches
    for i in z:
        for j,_ in enumerate(z[i]):
            assert z[i][j] == bootstrapped_data[i][j]['metadata']['mutation'].values[0]
            
    # create data loaders for each bootstrap sample
    data_loaders = {}

    for b in bootstrapped_data:

        loader = DataLoader([sample['graph'].dataset[0] for sample in bootstrapped_data[b]],
                            batch_size=256,
                            shuffle=False)
        
        data_loaders[b] = loader
        

    model = torch.load(model, map_location='cpu')


    res = evaluate_bootstrap_model(model, data_loaders, show_roc=False)
    
    return res

# %%
gcn_results = bootstrap_loop(model=model_path, dataset=dataset_path)

if split == "base":
    shuffle_edge_res = bootstrap_loop(model='../saved_models/control_models/Scrambled_graph_3-500epochs/F1=0.704_epoch=431.pth',
                    dataset=dataset_path,
                    remove_mpfs=False,
                    remove_sbmlcore=False,
                    shuffle_edges=True
                    )

    only_mpfs_res = bootstrap_loop(model='../saved_models/control_models/Only_MPfs_1-1500epochs/F1=0.771_epoch=398.pth',
                    dataset=dataset_path,
                    remove_mpfs=False,
                    remove_sbmlcore=True,
                    shuffle_edges=False
                    )

    only_sbmlcore_res = bootstrap_loop(model='../saved_models/control_models/Only_SBMLCore_5-2500epochs/F1=0.692_epoch=1278.pth',
                    dataset=dataset_path,
                    remove_mpfs=True,
                    remove_sbmlcore=False,
                    shuffle_edges=False
                    )

    no_ews_res = bootstrap_loop(model='../saved_models/control_models/final-model_no_ews-1500_epochs/F1=0.790_epoch=839.pth',
                    dataset=dataset_path,
                    remove_mpfs=False,
                    remove_sbmlcore=False,
                    shuffle_edges=False,
                    remove_ews=True
                    )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1535028090.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model, map_location='cpu')
# Bootstrap 0:
# Number predicted resistant = 106. Number labeled R = 106
# Number predicted susceptible = 94. Number labeled S = 94
# Sensitivity: 0.802
# Specificity: 0.777
# F1 Score: 0.802
# Confusion Matrix:
# [[73 21]
#  [21 85]]
#
#  ---
#
# Bootstrap 1:
# Number predicted resistant = 118. Number labeled R = 121
# Number predicted susceptible = 82. Number labeled S = 79
# Sensitivity: 0.851
# Specificity: 0.810
# F1 Score: 0.862
# Confusion Matrix:
# [[ 64  15]
#  [ 18 103]]
#
#  ---
#
# Bootstrap 2:
# Number predicted resistant = 100. Number labeled R = 90
# Number predicted susceptible = 100. Number labeled S = 110
# Sensitivity: 0.889
# Specificity: 0.818
# F1 Score: 0.842
# Confusion Matrix:
# [[90 20]
#  [10 80]]
#
#  ---
#
# Bootstrap 3:
# Number predicted resistant = 107. Number labeled R = 109
# Number predicted susceptible = 93. Number labeled S = 91
# Sensitivity: 0.835
# Specificity: 0.824
# F1 Score: 0.843
# Confusion Matrix:
# [[75 16]
#  [18 91]]
#
#  ---
#
# Bootstrap 4:
# Number predicted resistant = 96. Number labeled R = 92
# Number predicted susceptible = 104. Number labeled S = 108
# Sensitivity: 0.804
# Specificity: 0.796
# F1 Score: 0.787
# Confusion Matrix:
# [[86 22]
#  [18 74]]
#
#  ---
#
# Bootstrap 5:
# Number predicted resistant = 105. Number labeled R = 104
# Number predicted susceptible = 95. Number labeled S = 96
# Sensitivity: 0.846
# Specificity: 0.823
# F1 Score: 0.842
# Confusion Matrix:
# [[79 17]
#  [16 88]]
#
#  ---
#
# Bootstrap 6:
# Number predicted resistant = 93. Number labeled R = 93
# Number predicted susceptible = 107. Number labeled S = 107
# Sensitivity: 0.753
# Specificity: 0.785
# F1 Score: 0.753
# Confusion Matrix:
# [[84 23]
#  [23 70]]
#
#  ---
#
# Bootstrap 7:
# Number predicted resistant = 104. Number labeled R = 109
# Number predicted susceptible = 96. Number labeled S = 91
# Sensitivity: 0.807
# Specificity: 0.824
# F1 Score: 0.826
# Confusion Matrix:
# [[75 16]
#  [21 88]]
#
#  ---
#
# Bootstrap 8:
# Number predicted resistant = 105. Number labeled R = 101
# Number predicted susceptible = 95. Number labeled S = 99
# Sensitivity: 0.802
# Specificity: 0.758
# F1 Score: 0.786
# Confusion Matrix:
# [[75 24]
#  [20 81]]
#
#  ---
#
# Bootstrap 9:
# Number predicted resistant = 109. Number labeled R = 120
# Number predicted susceptible = 91. Number labeled S = 80
# Sensitivity: 0.758
# Specificity: 0.775
# F1 Score: 0.795
# Confusion Matrix:
# [[62 18]
#  [29 91]]
#
#  ---
#
# Adjusting edge index and attaching edge weights for cutoff distance 12
# Shuffling edges
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1535028090.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model, map_location='cpu')
# Bootstrap 0:
# Number predicted resistant = 127. Number labeled R = 106
# Number predicted susceptible = 73. Number labeled S = 94
# Sensitivity: 0.764
# Specificity: 0.511
# F1 Score: 0.695
# Confusion Matrix:
# [[48 46]
#  [25 81]]
#
#  ---
#
# Bootstrap 1:
# Number predicted resistant = 130. Number labeled R = 121
# Number predicted susceptible = 70. Number labeled S = 79
# Sensitivity: 0.777
# Specificity: 0.544
# F1 Score: 0.749
# Confusion Matrix:
# [[43 36]
#  [27 94]]
#
#  ---
#
# Bootstrap 2:
# Number predicted resistant = 107. Number labeled R = 90
# Number predicted susceptible = 93. Number labeled S = 110
# Sensitivity: 0.756
# Specificity: 0.645
# F1 Score: 0.690
# Confusion Matrix:
# [[71 39]
#  [22 68]]
#
#  ---
#
# Bootstrap 3:
# Number predicted resistant = 126. Number labeled R = 109
# Number predicted susceptible = 74. Number labeled S = 91
# Sensitivity: 0.761
# Specificity: 0.527
# F1 Score: 0.706
# Confusion Matrix:
# [[48 43]
#  [26 83]]
#
#  ---
#
# Bootstrap 4:
# Number predicted resistant = 116. Number labeled R = 92
# Number predicted susceptible = 84. Number labeled S = 108
# Sensitivity: 0.772
# Specificity: 0.583
# F1 Score: 0.683
# Confusion Matrix:
# [[63 45]
#  [21 71]]
#
#  ---
#
# Bootstrap 5:
# Number predicted resistant = 115. Number labeled R = 104
# Number predicted susceptible = 85. Number labeled S = 96
# Sensitivity: 0.721
# Specificity: 0.583
# F1 Score: 0.685
# Confusion Matrix:
# [[56 40]
#  [29 75]]
#
#  ---
#
# Bootstrap 6:
# Number predicted resistant = 108. Number labeled R = 93
# Number predicted susceptible = 92. Number labeled S = 107
# Sensitivity: 0.720
# Specificity: 0.617
# F1 Score: 0.667
# Confusion Matrix:
# [[66 41]
#  [26 67]]
#
#  ---
#
# Bootstrap 7:
# Number predicted resistant = 118. Number labeled R = 109
# Number predicted susceptible = 82. Number labeled S = 91
# Sensitivity: 0.743
# Specificity: 0.593
# F1 Score: 0.714
# Confusion Matrix:
# [[54 37]
#  [28 81]]
#
#  ---
#
# Bootstrap 8:
# Number predicted resistant = 120. Number labeled R = 101
# Number predicted susceptible = 80. Number labeled S = 99
# Sensitivity: 0.733
# Specificity: 0.535
# F1 Score: 0.670
# Confusion Matrix:
# [[53 46]
#  [27 74]]
#
#  ---
#
# Bootstrap 9:
# Number predicted resistant = 118. Number labeled R = 120
# Number predicted susceptible = 82. Number labeled S = 80
# Sensitivity: 0.700
# Specificity: 0.575
# F1 Score: 0.706
# Confusion Matrix:
# [[46 34]
#  [36 84]]
#
#  ---
#
# Adjusting edge index and attaching edge weights for cutoff distance 12
# Removing sbmlcore features from node features
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1535028090.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model, map_location='cpu')
# Bootstrap 0:
# Number predicted resistant = 107. Number labeled R = 106
# Number predicted susceptible = 93. Number labeled S = 94
# Sensitivity: 0.774
# Specificity: 0.734
# F1 Score: 0.770
# Confusion Matrix:
# [[69 25]
#  [24 82]]
#
#  ---
#
# Bootstrap 1:
# Number predicted resistant = 124. Number labeled R = 121
# Number predicted susceptible = 76. Number labeled S = 79
# Sensitivity: 0.835
# Specificity: 0.709
# F1 Score: 0.824
# Confusion Matrix:
# [[ 56  23]
#  [ 20 101]]
#
#  ---
#
# Bootstrap 2:
# Number predicted resistant = 102. Number labeled R = 90
# Number predicted susceptible = 98. Number labeled S = 110
# Sensitivity: 0.822
# Specificity: 0.745
# F1 Score: 0.771
# Confusion Matrix:
# [[82 28]
#  [16 74]]
#
#  ---
#
# Bootstrap 3:
# Number predicted resistant = 111. Number labeled R = 109
# Number predicted susceptible = 89. Number labeled S = 91
# Sensitivity: 0.826
# Specificity: 0.769
# F1 Score: 0.818
# Confusion Matrix:
# [[70 21]
#  [19 90]]
#
#  ---
#
# Bootstrap 4:
# Number predicted resistant = 99. Number labeled R = 92
# Number predicted susceptible = 101. Number labeled S = 108
# Sensitivity: 0.772
# Specificity: 0.741
# F1 Score: 0.743
# Confusion Matrix:
# [[80 28]
#  [21 71]]
#
#  ---
#
# Bootstrap 5:
# Number predicted resistant = 118. Number labeled R = 104
# Number predicted susceptible = 82. Number labeled S = 96
# Sensitivity: 0.837
# Specificity: 0.677
# F1 Score: 0.784
# Confusion Matrix:
# [[65 31]
#  [17 87]]
#
#  ---
#
# Bootstrap 6:
# Number predicted resistant = 105. Number labeled R = 93
# Number predicted susceptible = 95. Number labeled S = 107
# Sensitivity: 0.742
# Specificity: 0.664
# F1 Score: 0.697
# Confusion Matrix:
# [[71 36]
#  [24 69]]
#
#  ---
#
# Bootstrap 7:
# Number predicted resistant = 106. Number labeled R = 109
# Number predicted susceptible = 94. Number labeled S = 91
# Sensitivity: 0.752
# Specificity: 0.736
# F1 Score: 0.763
# Confusion Matrix:
# [[67 24]
#  [27 82]]
#
#  ---
#
# Bootstrap 8:
# Number predicted resistant = 109. Number labeled R = 101
# Number predicted susceptible = 91. Number labeled S = 99
# Sensitivity: 0.782
# Specificity: 0.697
# F1 Score: 0.752
# Confusion Matrix:
# [[69 30]
#  [22 79]]
#
#  ---
#
# Bootstrap 9:
# Number predicted resistant = 116. Number labeled R = 120
# Number predicted susceptible = 84. Number labeled S = 80
# Sensitivity: 0.742
# Specificity: 0.662
# F1 Score: 0.754
# Confusion Matrix:
# [[53 27]
#  [31 89]]
#
#  ---
#
# Adjusting edge index and attaching edge weights for cutoff distance 12
# Removing metapredictor features from node features
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1535028090.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model, map_location='cpu')
# Bootstrap 0:
# Number predicted resistant = 115. Number labeled R = 106
# Number predicted susceptible = 85. Number labeled S = 94
# Sensitivity: 0.736
# Specificity: 0.606
# F1 Score: 0.706
# Confusion Matrix:
# [[57 37]
#  [28 78]]
#
#  ---
#
# Bootstrap 1:
# Number predicted resistant = 112. Number labeled R = 121
# Number predicted susceptible = 88. Number labeled S = 79
# Sensitivity: 0.694
# Specificity: 0.646
# F1 Score: 0.721
# Confusion Matrix:
# [[51 28]
#  [37 84]]
#
#  ---
#
# Bootstrap 2:
# Number predicted resistant = 107. Number labeled R = 90
# Number predicted susceptible = 93. Number labeled S = 110
# Sensitivity: 0.711
# Specificity: 0.609
# F1 Score: 0.650
# Confusion Matrix:
# [[67 43]
#  [26 64]]
#
#  ---
#
# Bootstrap 3:
# Number predicted resistant = 105. Number labeled R = 109
# Number predicted susceptible = 95. Number labeled S = 91
# Sensitivity: 0.661
# Specificity: 0.637
# F1 Score: 0.673
# Confusion Matrix:
# [[58 33]
#  [37 72]]
#
#  ---
#
# Bootstrap 4:
# Number predicted resistant = 100. Number labeled R = 92
# Number predicted susceptible = 100. Number labeled S = 108
# Sensitivity: 0.641
# Specificity: 0.620
# F1 Score: 0.615
# Confusion Matrix:
# [[67 41]
#  [33 59]]
#
#  ---
#
# Bootstrap 5:
# Number predicted resistant = 109. Number labeled R = 104
# Number predicted susceptible = 91. Number labeled S = 96
# Sensitivity: 0.712
# Specificity: 0.635
# F1 Score: 0.695
# Confusion Matrix:
# [[61 35]
#  [30 74]]
#
#  ---
#
# Bootstrap 6:
# Number predicted resistant = 99. Number labeled R = 93
# Number predicted susceptible = 101. Number labeled S = 107
# Sensitivity: 0.613
# Specificity: 0.607
# F1 Score: 0.594
# Confusion Matrix:
# [[65 42]
#  [36 57]]
#
#  ---
#
# Bootstrap 7:
# Number predicted resistant = 106. Number labeled R = 109
# Number predicted susceptible = 94. Number labeled S = 91
# Sensitivity: 0.651
# Specificity: 0.615
# F1 Score: 0.660
# Confusion Matrix:
# [[56 35]
#  [38 71]]
#
#  ---
#
# Bootstrap 8:
# Number predicted resistant = 111. Number labeled R = 101
# Number predicted susceptible = 89. Number labeled S = 99
# Sensitivity: 0.772
# Specificity: 0.667
# F1 Score: 0.736
# Confusion Matrix:
# [[66 33]
#  [23 78]]
#
#  ---
#
# Bootstrap 9:
# Number predicted resistant = 106. Number labeled R = 120
# Number predicted susceptible = 94. Number labeled S = 80
# Sensitivity: 0.667
# Specificity: 0.675
# F1 Score: 0.708
# Confusion Matrix:
# [[54 26]
#  [40 80]]
#
#  ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1535028090.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model, map_location='cpu')
# Bootstrap 0:
# Number predicted resistant = 92. Number labeled R = 106
# Number predicted susceptible = 108. Number labeled S = 94
# Sensitivity: 0.736
# Specificity: 0.851
# F1 Score: 0.788
# Confusion Matrix:
# [[80 14]
#  [28 78]]
#
#  ---
#
# Bootstrap 1:
# Number predicted resistant = 117. Number labeled R = 121
# Number predicted susceptible = 83. Number labeled S = 79
# Sensitivity: 0.802
# Specificity: 0.747
# F1 Score: 0.815
# Confusion Matrix:
# [[59 20]
#  [24 97]]
#
#  ---
#
# Bootstrap 2:
# Number predicted resistant = 95. Number labeled R = 90
# Number predicted susceptible = 105. Number labeled S = 110
# Sensitivity: 0.778
# Specificity: 0.773
# F1 Score: 0.757
# Confusion Matrix:
# [[85 25]
#  [20 70]]
#
#  ---
#
# Bootstrap 3:
# Number predicted resistant = 98. Number labeled R = 109
# Number predicted susceptible = 102. Number labeled S = 91
# Sensitivity: 0.752
# Specificity: 0.824
# F1 Score: 0.792
# Confusion Matrix:
# [[75 16]
#  [27 82]]
#
#  ---
#
# Bootstrap 4:
# Number predicted resistant = 89. Number labeled R = 92
# Number predicted susceptible = 111. Number labeled S = 108
# Sensitivity: 0.750
# Specificity: 0.815
# F1 Score: 0.762
# Confusion Matrix:
# [[88 20]
#  [23 69]]
#
#  ---
#
# Bootstrap 5:
# Number predicted resistant = 100. Number labeled R = 104
# Number predicted susceptible = 100. Number labeled S = 96
# Sensitivity: 0.769
# Specificity: 0.792
# F1 Score: 0.784
# Confusion Matrix:
# [[76 20]
#  [24 80]]
#
#  ---
#
# Bootstrap 6:
# Number predicted resistant = 92. Number labeled R = 93
# Number predicted susceptible = 108. Number labeled S = 107
# Sensitivity: 0.688
# Specificity: 0.738
# F1 Score: 0.692
# Confusion Matrix:
# [[79 28]
#  [29 64]]
#
#  ---
#
# Bootstrap 7:
# Number predicted resistant = 96. Number labeled R = 109
# Number predicted susceptible = 104. Number labeled S = 91
# Sensitivity: 0.780
# Specificity: 0.879
# F1 Score: 0.829
# Confusion Matrix:
# [[80 11]
#  [24 85]]
#
#  ---
#
# Bootstrap 8:
# Number predicted resistant = 93. Number labeled R = 101
# Number predicted susceptible = 107. Number labeled S = 99
# Sensitivity: 0.762
# Specificity: 0.838
# F1 Score: 0.794
# Confusion Matrix:
# [[83 16]
#  [24 77]]
#
#  ---
#
# Bootstrap 9:
# Number predicted resistant = 104. Number labeled R = 120
# Number predicted susceptible = 96. Number labeled S = 80
# Sensitivity: 0.758
# Specificity: 0.838
# F1 Score: 0.812
# Confusion Matrix:
# [[67 13]
#  [29 91]]
#
#  ---

# %% [markdown]
# ### Evaluate vs Carter et al results

# %%
# model performance from carter et al.
carter_results_choices = {
    "base": "../data/carter-results/carter-model-results.csv",
    "cluster": "../data/carter-results/carter-clustered-results-test.csv",
    "codon": "../data/carter-results/carter-codon-results-test.csv"
}

model_results = pd.read_csv(carter_results_choices[split])

# %%
def compute_f1(tp, fp, fn):
    precision = tp / (tp + fp) if (tp + fp) else 0
    recall = tp / (tp + fn) if (tp + fn) else 0
    return 2 * precision * recall / (precision + recall) if (precision + recall) else 0

# %%
model_results['f1_mean'] = model_results.apply(lambda row: 100*compute_f1(row["TP"], row["FP"], row["FN"]), axis=1)

# %%
def confidence_interval_width(data, confidence=0.95):
    arr = np.array(data)
    n = len(arr)
    sem = stats.sem(arr)
    # h = sem * stats.t.ppf((1 + confidence) / 2., n-1)
    h = 1.96 * sem
    return h

# %%
for m in ['LR', 'NN', 'XB']:
    f1_vals = model_results[
        (model_results['model'] == m) & (
            model_results['dataset'].isin([f"test_{n}" for n in range(10)])
            )
        ]['f1_mean'].values
    
    roc_auc_vals = model_results[
        (model_results['model'] == m) & (
            model_results['dataset'].isin([f"test_{n}" for n in range(10)])
            )
        ]['roc_auc_mean'].values

    bootstrap_f1_mean = f1_vals.mean()

    model_results.loc[
            ((model_results['model'] == m) & (model_results['dataset'] == "bootstrapped")), "f1_mean"
            ] = bootstrap_f1_mean
    
    model_results.loc[
            ((model_results['model'] == m) & (model_results['dataset'] == "bootstrapped")), "f1_std"
            ] = confidence_interval_width(f1_vals)
    
    model_results.loc[
            ((model_results['model'] == m) & (model_results['dataset'] == "bootstrapped")), "roc_auc_std"
            ] = confidence_interval_width(roc_auc_vals)

# %%
model_results = model_results[
    [
        "model",
        "dataset",
        "f1_mean",
        "f1_std",
        "sensitivity_mean",
        "sensitivity_std",
        "specificity_mean",
        "specificity_std",
        "roc_auc_mean",
        "roc_auc_std",
        "TN",
        "FP",
        "FN",
        "TP"
    ]
]

# %%
gcn_sens_width = confidence_interval_width(gcn_results['sensitivity'])*100
gcn_spec_width = confidence_interval_width(gcn_results['specificity'])*100
gcn_f1_width = confidence_interval_width(gcn_results['f1'])*100
gcn_roc_auc_width = confidence_interval_width(gcn_results['roc_auc'])*100

# %%
# add gcn results to df
gcn_results_row = ["GCN", 
                   "bootstrapped",
                    np.mean(gcn_results['f1'])*100,
                    gcn_f1_width,
                    np.mean(gcn_results['sensitivity'])*100,
                    gcn_sens_width,
                    np.mean(gcn_results['specificity'])*100,
                    gcn_spec_width,
                    np.mean(gcn_results['roc_auc'])*100,
                    gcn_roc_auc_width,
                    np.nan,
                    np.nan,
                    np.nan,
                    np.nan,
                   ]

model_results.loc[len(model_results)] = gcn_results_row

# %%
# add gcn bootstrapping results to df
for idx in range(10):
    row = {
        "model": "GCN",
        "dataset": f"test_{idx}",
        "f1_mean": gcn_results['f1'][idx]*100,
        "f1_std": None,
        "sensitivity_mean": gcn_results['sensitivity'][idx]*100,
        "sensitivity_std": None,
        "specificity_mean": gcn_results['specificity'][idx]*100,
        "specificity_std": None,
        "roc_auc_mean": gcn_results['roc_auc'][idx]*100,
        "roc_auc_std": None,
        "TN": None,
        "FP": None,
        "FN": None,
        "TP": None,
    }
    model_results.loc[len(model_results)] = row
# Out:
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/1048713041.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_results.loc[len(model_results)] = row

# %%
# find significant differences between models, paired t-tests
from scipy.stats import ttest_rel

models = ['LR', 'NN', 'XB', 'GCN']
bsap_list = [f"test_{n}" for n in range(10)]
metrics = ['f1_mean', 'sensitivity_mean', 'specificity_mean', 'roc_auc_mean']
for ind, m in enumerate(models):
    for m_2 in models[ind+1:]:
        if m == m_2 or (m != 'GCN' and m_2 != 'GCN'):
            continue
        for metric in metrics:
            t_stat, p_val = ttest_rel(
                model_results.loc[(model_results['model'] == m) & (model_results['dataset'].isin(bsap_list)), metric],
                model_results.loc[(model_results['model'] == m_2) & (model_results['dataset'].isin(bsap_list)), metric]
            )
            if p_val <= 0.05:
                print(f"{m} vs {m_2} {metric}: t-statistic = {t_stat:.3f}, p-value = {p_val}")
                if p_val <= 0.001:
                    stars = '***'
                elif p_val <= 0.01:
                    stars = '**'
                elif p_val <= 0.05:
                    stars = '*'
                else:
                    stars = ''
                print(f"Significance: {stars}")
# Out:
# LR vs GCN f1_mean: t-statistic = -6.231, p-value = 0.00015305978182598266
# Significance: ***
# LR vs GCN sensitivity_mean: t-statistic = -3.362, p-value = 0.008368306277418898
# Significance: **
# LR vs GCN specificity_mean: t-statistic = -8.054, p-value = 2.096545635164292e-05
# Significance: ***
# NN vs GCN f1_mean: t-statistic = -15.396, p-value = 8.992252647362142e-08
# Significance: ***
# NN vs GCN sensitivity_mean: t-statistic = -5.446, p-value = 0.00040764451022776333
# Significance: ***
# NN vs GCN specificity_mean: t-statistic = -15.254, p-value = 9.749018229279952e-08
# Significance: ***
# NN vs GCN roc_auc_mean: t-statistic = -6.262, p-value = 0.00014748183972504986
# Significance: ***

# %% [markdown]
# ### Evaluate full Test set for GCN models

# %%
loader = DataLoader([data['test'][sample]['graph'].dataset[0] for sample in data['test']],
                          batch_size=256,
                          shuffle=False)

model = torch.load(model_path, map_location='cpu')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /var/folders/l5/vrm1h_ss1_l4hs0jcrxrr_0c0000gn/T/ipykernel_59460/4008811418.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path, map_location='cpu')

# %%
test_sens, test_spec, test_f1, test_cm = evaluation.calculate_metrics(model, loader)
fpr, tpr, test_roc_auc = evaluation.calculate_roc(model, loader)
# Out:
# Number predicted resistant = 103. Number labeled R = 103
# Number predicted susceptible = 97. Number labeled S = 97
# Sensitivity: 0.816
# Specificity: 0.804
# F1 Score: 0.816
# Confusion Matrix:
# [[78 19]
#  [19 84]]

# %%
# add gcn test set performance to df

gcn_test_row = ["GCN", 
                   "test",
                    test_f1*100,
                    gcn_f1_width,
                    test_sens*100,
                    gcn_sens_width,
                    test_spec*100,
                    gcn_spec_width,
                    test_roc_auc*100,
                    gcn_roc_auc_width,
                    test_cm[0, 0],
                    test_cm[0, 1],
                    test_cm[1, 0],
                    test_cm[1, 1],
                   ]

model_results.loc[len(model_results)] = gcn_test_row

# %%
model_results.to_csv(f"../data/results/{split}_model_results.csv", index=False)
model_results
# Out:
#    model       dataset    f1_mean    f1_std  sensitivity_mean  \
# 0     LR          test  77.358491       NaN         79.611650
# 1     NN          test  70.588235       NaN         75.728155
# 2     XB          test  80.193237       NaN         80.582524
# 3     LR        test_0  75.576037       NaN         77.358491
# 4     LR        test_1  82.258065       NaN         84.297521
# 5     LR        test_2  75.126904       NaN         82.222222
# 6     LR        test_3  80.909091       NaN         81.651376
# 7     LR        test_4  73.469388       NaN         78.260870
# 8     LR        test_5  77.477477       NaN         82.692308
# 9     LR        test_6  70.408163       NaN         74.193548
# 10    LR        test_7  77.625571       NaN         77.981651
# 11    LR        test_8  78.468900       NaN         81.188119
# 12    LR        test_9  76.394850       NaN         74.166667
# 13    NN        test_0  70.852018       NaN         74.528302
# 14    NN        test_1  76.377953       NaN         80.165289
# 15    NN        test_2  71.568627       NaN         81.111111
# 16    NN        test_3  75.982533       NaN         79.816514
# 17    NN        test_4  68.932039       NaN         77.173913
# 18    NN        test_5  73.214286       NaN         78.846154
# 19    NN        test_6  66.666667       NaN         76.344086
# 20    NN        test_7  72.888889       NaN         75.229358
# 21    NN        test_8  73.488372       NaN         78.217822
# 22    NN        test_9  69.456067       NaN         69.166667
# 23    XB        test_0  80.952381       NaN         80.188679
# 24    XB        test_1  87.500000       NaN         86.776860
# 25    XB        test_2  78.888889       NaN         78.888889
# 26    XB        test_3  84.651163       NaN         83.486239
# 27    XB        test_4  76.190476       NaN         78.260870
# 28    XB        test_5  80.788177       NaN         78.846154
# 29    XB        test_6  75.392670       NaN         77.419355
# 30    XB        test_7  83.962264       NaN         81.651376
# 31    XB        test_8  81.904762       NaN         85.148515
# 32    XB        test_9  80.176211       NaN         75.833333
# 33    LR  bootstrapped  76.771444  2.137137         79.401277
# 34    NN  bootstrapped  71.942745  1.908209         77.059922
# 35    XB  bootstrapped  81.040699  2.309090         80.650027
# 36   GCN  bootstrapped  81.379955  2.126958         81.477206
# 37   GCN        test_0  80.188679       NaN         80.188679
# 38   GCN        test_1  86.192469       NaN         85.123967
# 39   GCN        test_2  84.210526       NaN         88.888889
# 40   GCN        test_3  84.259259       NaN         83.486239
# 41   GCN        test_4  78.723404       NaN         80.434783
# 42   GCN        test_5  84.210526       NaN         84.615385
# 43   GCN        test_6  75.268817       NaN         75.268817
# 44   GCN        test_7  82.629108       NaN         80.733945
# 45   GCN        test_8  78.640777       NaN         80.198020
# 46   GCN        test_9  79.475983       NaN         75.833333
# 47   GCN          test  81.553398  2.126958         81.553398
#
#     sensitivity_std  specificity_mean  specificity_std  roc_auc_mean  \
# 0               NaN         72.164948              NaN     82.784506
# 1               NaN         58.762887              NaN     75.097588
# 2               NaN         78.350515              NaN     82.234011
# 3               NaN         69.148936              NaN     80.750703
# 4               NaN         68.354430              NaN     85.594727
# 5               NaN         70.000000              NaN     85.606061
# 6               NaN         75.824176              NaN     82.810767
# 7               NaN         70.370370              NaN     82.357085
# 8               NaN         66.666667              NaN     84.805689
# 9               NaN         68.224299              NaN     77.710783
# 10              NaN         72.527473              NaN     81.963908
# 11              NaN         73.737374              NaN     82.058206
# 12              NaN         70.000000              NaN     78.906250
# 13              NaN         59.574468              NaN     75.827981
# 14              NaN         54.430380              NaN     78.423475
# 15              NaN         62.727273              NaN     79.646465
# 16              NaN         63.736264              NaN     79.574554
# 17              NaN         60.185185              NaN     76.846820
# 18              NaN         60.416667              NaN     78.625801
# 19              NaN         54.205607              NaN     72.625867
# 20              NaN         62.637363              NaN     77.175118
# 21              NaN         64.646465              NaN     75.967597
# 22              NaN         55.000000              NaN     63.968750
# 23              NaN         79.787234              NaN     82.346447
# 24              NaN         82.278481              NaN     86.211947
# 25              NaN         82.727273              NaN     82.757576
# 26              NaN         83.516484              NaN     85.341264
# 27              NaN         76.851852              NaN     80.485105
# 28              NaN         82.291667              NaN     83.383413
# 29              NaN         75.700935              NaN     78.605165
# 30              NaN         84.615385              NaN     85.462244
# 31              NaN         76.767677              NaN     85.638564
# 32              NaN         80.000000              NaN     80.552083
# 33         2.196483         70.485372         1.725528     82.256418
# 34         2.174477         59.755967         2.438712     75.868243
# 35         2.193639         80.453699         1.942238     83.078381
# 36         2.592420         79.900912         1.507957     81.636561
# 37              NaN         77.659574              NaN     81.101967
# 38              NaN         81.012658              NaN     84.684590
# 39              NaN         81.818182              NaN     86.555556
# 40              NaN         82.417582              NaN     84.534731
# 41              NaN         79.629630              NaN     80.545491
# 42              NaN         82.291667              NaN     83.754006
# 43              NaN         78.504673              NaN     75.469802
# 44              NaN         82.417582              NaN     81.288436
# 45              NaN         75.757576              NaN     81.108111
# 46              NaN         77.500000              NaN     77.322917
# 47         2.592420         80.412371         1.507957     82.824542
#
#     roc_auc_std    TN    FP    FN     TP
# 0           NaN  70.0  27.0  21.0   82.0
# 1           NaN  57.0  40.0  25.0   78.0
# 2           NaN  76.0  21.0  20.0   83.0
# 3           NaN  65.0  29.0  24.0   82.0
# 4           NaN  54.0  25.0  19.0  102.0
# 5           NaN  77.0  33.0  16.0   74.0
# 6           NaN  69.0  22.0  20.0   89.0
# 7           NaN  76.0  32.0  20.0   72.0
# 8           NaN  64.0  32.0  18.0   86.0
# 9           NaN  73.0  34.0  24.0   69.0
# 10          NaN  66.0  25.0  24.0   85.0
# 11          NaN  73.0  26.0  19.0   82.0
# 12          NaN  56.0  24.0  31.0   89.0
# 13          NaN  56.0  38.0  27.0   79.0
# 14          NaN  43.0  36.0  24.0   97.0
# 15          NaN  69.0  41.0  17.0   73.0
# 16          NaN  58.0  33.0  22.0   87.0
# 17          NaN  65.0  43.0  21.0   71.0
# 18          NaN  58.0  38.0  22.0   82.0
# 19          NaN  58.0  49.0  22.0   71.0
# 20          NaN  57.0  34.0  27.0   82.0
# 21          NaN  64.0  35.0  22.0   79.0
# 22          NaN  44.0  36.0  37.0   83.0
# 23          NaN  75.0  19.0  21.0   85.0
# 24          NaN  65.0  14.0  16.0  105.0
# 25          NaN  91.0  19.0  19.0   71.0
# 26          NaN  76.0  15.0  18.0   91.0
# 27          NaN  83.0  25.0  20.0   72.0
# 28          NaN  79.0  17.0  22.0   82.0
# 29          NaN  81.0  26.0  21.0   72.0
# 30          NaN  77.0  14.0  20.0   89.0
# 31          NaN  76.0  23.0  15.0   86.0
# 32          NaN  64.0  16.0  29.0   91.0
# 33     1.645818   NaN   NaN   NaN    NaN
# 34     2.899306   NaN   NaN   NaN    NaN
# 35     1.613956   NaN   NaN   NaN    NaN
# 36     2.115863   NaN   NaN   NaN    NaN
# 37          NaN   NaN   NaN   NaN    NaN
# 38          NaN   NaN   NaN   NaN    NaN
# 39          NaN   NaN   NaN   NaN    NaN
# 40          NaN   NaN   NaN   NaN    NaN
# 41          NaN   NaN   NaN   NaN    NaN
# 42          NaN   NaN   NaN   NaN    NaN
# 43          NaN   NaN   NaN   NaN    NaN
# 44          NaN   NaN   NaN   NaN    NaN
# 45          NaN   NaN   NaN   NaN    NaN
# 46          NaN   NaN   NaN   NaN    NaN
# 47     2.115863  78.0  19.0  19.0   84.0

# %% [markdown]
# ### Create results df for control models

# %%
def summarise_bootstrap_results(res, model_name, dataset_name="bootstrapped"):
    return {
        "model": model_name,
        "dataset": dataset_name,
        "f1_mean": np.mean(res['f1'])*100,
        "f1_std": confidence_interval_width(res['f1'])*100,
        "sensitivity_mean": np.mean(res['sensitivity'])*100,
        "sensitivity_std": confidence_interval_width(res['sensitivity'])*100,
        "specificity_mean": np.mean(res['specificity'])*100,
        "specificity_std": confidence_interval_width(res['specificity'])*100,
        "roc_auc_mean": np.mean(res['roc_auc'])*100,
        "roc_auc_std": confidence_interval_width(res['roc_auc'])*100,
        "TN": np.nan,
        "FP": np.nan,
        "FN": np.nan,
        "TP": np.nan,
    }

def summarise_single_bootstrap(res, model_name, idx):
    return {
        "model": model_name,
        "dataset": f"test_{idx}",
        "f1_mean": res['f1'][idx]*100,
        "f1_std": None,
        "sensitivity_mean": res['sensitivity'][idx]*100,
        "sensitivity_std": None,
        "specificity_mean": res['specificity'][idx]*100,
        "specificity_std": None,
        "roc_auc_mean": res['roc_auc'][idx]*100,
        "roc_auc_std": None,
        "TN": np.nan,
        "FP": np.nan,
        "FN": np.nan,
        "TP": np.nan,
    }

if split == "base":
    control_results_rows = [
        summarise_bootstrap_results(gcn_results, "GCN"),
        summarise_bootstrap_results(shuffle_edge_res, "GCN-shuffleEdges"),
        summarise_bootstrap_results(only_mpfs_res, "GCN-onlyMPFs"),
        summarise_bootstrap_results(only_sbmlcore_res, "GCN-onlySBMLCore"),
        summarise_bootstrap_results(no_ews_res, "GCN-noEWs")
    ]

    # Add per-bootstrap (test_0 to test_9) rows for each control model
    for res, name in [
        (gcn_results, "GCN"),
        (shuffle_edge_res, "GCN-shuffleEdges"),
        (only_mpfs_res, "GCN-onlyMPFs"),
        (only_sbmlcore_res, "GCN-onlySBMLCore"),
        (no_ews_res, "GCN-noEWs"),
    ]:
        for idx in range(10):
            control_results_rows.append(summarise_single_bootstrap(res, name, idx))

    control_results_df = pd.DataFrame(control_results_rows)
    control_results_df.to_csv(f"../data/results/{split}_control_model_results.csv", index=False)
    display(control_results_df)
# Out:
#                model       dataset    f1_mean    f1_std  sensitivity_mean  \
# 0                GCN  bootstrapped  81.379955  2.126958         81.477206
# 1   GCN-shuffleEdges  bootstrapped  69.645337  1.491202         74.471495
# 2       GCN-onlyMPFs  bootstrapped  76.770759  2.270525         78.825575
# 3   GCN-onlySBMLCore  bootstrapped  67.570036  2.874331         68.577916
# 4          GCN-noEWs  bootstrapped  78.262514  2.416679         75.755022
# 5                GCN        test_0  80.188679       NaN         80.188679
# 6                GCN        test_1  86.192469       NaN         85.123967
# 7                GCN        test_2  84.210526       NaN         88.888889
# 8                GCN        test_3  84.259259       NaN         83.486239
# 9                GCN        test_4  78.723404       NaN         80.434783
# 10               GCN        test_5  84.210526       NaN         84.615385
# 11               GCN        test_6  75.268817       NaN         75.268817
# 12               GCN        test_7  82.629108       NaN         80.733945
# 13               GCN        test_8  78.640777       NaN         80.198020
# 14               GCN        test_9  79.475983       NaN         75.833333
# 15  GCN-shuffleEdges        test_0  69.527897       NaN         76.415094
# 16  GCN-shuffleEdges        test_1  74.900398       NaN         77.685950
# 17  GCN-shuffleEdges        test_2  69.035533       NaN         75.555556
# 18  GCN-shuffleEdges        test_3  70.638298       NaN         76.146789
# 19  GCN-shuffleEdges        test_4  68.269231       NaN         77.173913
# 20  GCN-shuffleEdges        test_5  68.493151       NaN         72.115385
# 21  GCN-shuffleEdges        test_6  66.666667       NaN         72.043011
# 22  GCN-shuffleEdges        test_7  71.365639       NaN         74.311927
# 23  GCN-shuffleEdges        test_8  66.968326       NaN         73.267327
# 24  GCN-shuffleEdges        test_9  70.588235       NaN         70.000000
# 25      GCN-onlyMPFs        test_0  76.995305       NaN         77.358491
# 26      GCN-onlyMPFs        test_1  82.448980       NaN         83.471074
# 27      GCN-onlyMPFs        test_2  77.083333       NaN         82.222222
# 28      GCN-onlyMPFs        test_3  81.818182       NaN         82.568807
# 29      GCN-onlyMPFs        test_4  74.345550       NaN         77.173913
# 30      GCN-onlyMPFs        test_5  78.378378       NaN         83.653846
# 31      GCN-onlyMPFs        test_6  69.696970       NaN         74.193548
# 32      GCN-onlyMPFs        test_7  76.279070       NaN         75.229358
# 33      GCN-onlyMPFs        test_8  75.238095       NaN         78.217822
# 34      GCN-onlyMPFs        test_9  75.423729       NaN         74.166667
# 35  GCN-onlySBMLCore        test_0  70.588235       NaN         73.584906
# 36  GCN-onlySBMLCore        test_1  72.103004       NaN         69.421488
# 37  GCN-onlySBMLCore        test_2  64.974619       NaN         71.111111
# 38  GCN-onlySBMLCore        test_3  67.289720       NaN         66.055046
# 39  GCN-onlySBMLCore        test_4  61.458333       NaN         64.130435
# 40  GCN-onlySBMLCore        test_5  69.483568       NaN         71.153846
# 41  GCN-onlySBMLCore        test_6  59.375000       NaN         61.290323
# 42  GCN-onlySBMLCore        test_7  66.046512       NaN         65.137615
# 43  GCN-onlySBMLCore        test_8  73.584906       NaN         77.227723
# 44  GCN-onlySBMLCore        test_9  70.796460       NaN         66.666667
# 45         GCN-noEWs        test_0  78.787879       NaN         73.584906
# 46         GCN-noEWs        test_1  81.512605       NaN         80.165289
# 47         GCN-noEWs        test_2  75.675676       NaN         77.777778
# 48         GCN-noEWs        test_3  79.227053       NaN         75.229358
# 49         GCN-noEWs        test_4  76.243094       NaN         75.000000
# 50         GCN-noEWs        test_5  78.431373       NaN         76.923077
# 51         GCN-noEWs        test_6  69.189189       NaN         68.817204
# 52         GCN-noEWs        test_7  82.926829       NaN         77.981651
# 53         GCN-noEWs        test_8  79.381443       NaN         76.237624
# 54         GCN-noEWs        test_9  81.250000       NaN         75.833333
#
#     sensitivity_std  specificity_mean  specificity_std  roc_auc_mean  \
# 0          2.592420         79.900912         1.507957     81.636561
# 1          1.577684         57.151184         2.612056     73.578124
# 2          2.371748         71.346975         2.312288     80.175824
# 3          2.982492         63.187211         1.527872     66.861852
# 4          1.891198         80.946063         2.855338     79.572648
# 5               NaN         77.659574              NaN     81.101967
# 6               NaN         81.012658              NaN     84.684590
# 7               NaN         81.818182              NaN     86.555556
# 8               NaN         82.417582              NaN     84.534731
# 9               NaN         79.629630              NaN     80.545491
# 10              NaN         82.291667              NaN     83.754006
# 11              NaN         78.504673              NaN     75.469802
# 12              NaN         82.417582              NaN     81.288436
# 13              NaN         75.757576              NaN     81.108111
# 14              NaN         77.500000              NaN     77.322917
# 15              NaN         51.063830              NaN     72.551184
# 16              NaN         54.430380              NaN     73.218956
# 17              NaN         64.545455              NaN     78.252525
# 18              NaN         52.747253              NaN     73.666700
# 19              NaN         58.333333              NaN     74.295491
# 20              NaN         58.333333              NaN     72.906651
# 21              NaN         61.682243              NaN     69.400060
# 22              NaN         59.340659              NaN     74.392580
# 23              NaN         53.535354              NaN     75.107511
# 24              NaN         57.500000              NaN     71.989583
# 25              NaN         73.404255              NaN     77.870333
# 26              NaN         70.886076              NaN     82.414479
# 27              NaN         74.545455              NaN     85.101010
# 28              NaN         76.923077              NaN     82.427664
# 29              NaN         74.074074              NaN     79.287440
# 30              NaN         67.708333              NaN     83.323317
# 31              NaN         66.355140              NaN     74.103105
# 32              NaN         73.626374              NaN     79.322512
# 33              NaN         69.696970              NaN     79.647965
# 34              NaN         66.250000              NaN     78.260417
# 35              NaN         60.638298              NaN     68.446407
# 36              NaN         64.556962              NaN     69.693483
# 37              NaN         60.909091              NaN     67.262626
# 38              NaN         63.736264              NaN     67.889908
# 39              NaN         62.037037              NaN     64.643720
# 40              NaN         63.541667              NaN     69.701522
# 41              NaN         60.747664              NaN     64.094061
# 42              NaN         61.538462              NaN     63.968142
# 43              NaN         66.666667              NaN     69.876988
# 44              NaN         67.500000              NaN     63.041667
# 45              NaN         85.106383              NaN     79.175030
# 46              NaN         74.683544              NaN     78.543781
# 47              NaN         77.272727              NaN     80.919192
# 48              NaN         82.417582              NaN     80.723863
# 49              NaN         81.481481              NaN     78.240741
            model_metrics['roc_auc_mean'].values,
            model_metrics['roc_auc_std'].astype(float).values
        ),
    }
    fig, axs = plt.subplots(2, 2, figsize=(10.5,7))
    # fig, axs = plt.subplots(1, 4, figsize=(10,3))

    for i, (metric, (vals, errs)) in enumerate(metrics.items()):
        ax = axs[i // 2, i % 2]
        x = np.arange(len(models))
        
        bars = ax.bar(x, vals, yerr=errs, capsize=2, width=0.85, 
                    color='white', edgecolor=colours,
                    linewidth=2,
                    alpha=0.7
                    )

        # metric values labelled above bars
        for bar, value, error in zip(bars, vals, errs):
            ax.text(bar.get_x() + bar.get_width() / 2, value + error + 1, f'{value:.1f}',
                    ha='center', va='bottom',
                    fontsize=12,
                    # color='black'
                    )

        # metric label below x axis, x ticks but no labels
        ax.set_xlabel(metric, labelpad=6)
        ax.set_xticks(np.arange(len(models)))
        ax.set_xticklabels([])
        
        ax.set_ylim(0, max(vals + errs) + 10)
        ax.spines[['top', 'right', 'left']].set_visible(False)
        ax.tick_params(left=False, labelleft=False)

    # legend
    legend_elements = [Patch(facecolor="white", alpha=0.5, edgecolor=colours[i], linewidth=2, 
                            #  label=models[i]
                            label=labels[i]
                            ) for i in range(len(models))]
    fig.legend(handles=legend_elements, loc='upper right', 
            frameon=False)

    plt.tight_layout(rect=[0, 0, 0.92,1])  # space for legend on right
    plt.show()

# %%
# GCN results vs classical machine learning models

model_metrics = model_results[model_results['dataset'] == 'bootstrapped'][::-1] 

labels = model_metrics['model'].values

plot_metric_bars(model_metrics= model_metrics,
                 labels=labels
                 )

# %%
# GCN results vs control models
if split == "base":
        model_metrics = control_results_df[control_results_df['dataset'] == 'bootstrapped']
        model_order = ['GCN', 'GCN-onlyMPFs', 'GCN-onlySBMLCore', 'GCN-shuffleEdges', 'GCN-noEWs']
        model_metrics = model_metrics.set_index('model').loc[model_order].reset_index()

        labels = [
                'Full GCN',
                'MPFs only',
                'No MPFs',
                'Scrambled Edges',
                'No Edge Weights'
                ]

        plot_metric_bars(model_metrics= model_metrics,
                        labels=labels
                        )

# %% [markdown]
# ### Get significant differences for control models

# %%
if split == "base":
    models = control_results_df[control_results_df['dataset'] == 'bootstrapped']['model'].values
    bsap_list = [f"test_{n}" for n in range(10)]
    metrics = ['f1_mean', 'sensitivity_mean', 'specificity_mean', 'roc_auc_mean']
    for ind, model in enumerate(models):
        for model_2 in models[ind+1:]:
            if model == model_2 or (model != 'GCN' and model_2 != 'GCN'):
                continue
            for metric in metrics:
                t_stat, p_val = ttest_rel(
                    control_results_df.loc[(control_results_df['model'] == model) & (control_results_df['dataset'].isin(bsap_list)), metric],
                    control_results_df.loc[(control_results_df['model'] == model_2) & (control_results_df['dataset'].isin(bsap_list)), metric]
                )
                if p_val <= 0.05:
                    print(f"{model} vs {model_2} {metric}: t-statistic = {t_stat:.3f}, p-value = {p_val}")
                    if p_val <= 0.001:
                        stars = '***'
                    elif p_val <= 0.01:
                        stars = '**'
                    elif p_val <= 0.05:
                        stars = '*'
                    else:
                        stars = ''
                    print(f"Significance: {stars}")
# Out:
# GCN vs GCN-shuffleEdges f1_mean: t-statistic = 15.381, p-value = 9.073069261142867e-08
# Significance: ***
# GCN vs GCN-shuffleEdges sensitivity_mean: t-statistic = 6.308, p-value = 0.00013961770216253637
# Significance: ***
# GCN vs GCN-shuffleEdges specificity_mean: t-statistic = 17.390, p-value = 3.10484454128761e-08
# Significance: ***
# GCN vs GCN-shuffleEdges roc_auc_mean: t-statistic = 11.055, p-value = 1.5434757326364893e-06
# Significance: ***
# GCN vs GCN-onlyMPFs f1_mean: t-statistic = 9.527, p-value = 5.349257740809129e-06
# Significance: ***
# GCN vs GCN-onlyMPFs sensitivity_mean: t-statistic = 4.226, p-value = 0.002219103779853227
# Significance: **
# GCN vs GCN-onlyMPFs specificity_mean: t-statistic = 7.966, p-value = 2.289321411565749e-05
# Significance: ***
# GCN vs GCN-onlyMPFs roc_auc_mean: t-statistic = 4.118, p-value = 0.0026073074997659002
# Significance: **
# GCN vs GCN-onlySBMLCore f1_mean: t-statistic = 9.633, p-value = 4.882040034076683e-06
# Significance: ***
# GCN vs GCN-onlySBMLCore sensitivity_mean: t-statistic = 8.164, p-value = 1.8819845485788685e-05
# Significance: ***
# GCN vs GCN-onlySBMLCore specificity_mean: t-statistic = 13.026, p-value = 3.817050259796909e-07
# Significance: ***
# GCN vs GCN-onlySBMLCore roc_auc_mean: t-statistic = 17.935, p-value = 2.3683625179389857e-08
# Significance: ***
# GCN vs GCN-noEWs f1_mean: t-statistic = 2.884, p-value = 0.018053109068193133
# Significance: *
# GCN vs GCN-noEWs sensitivity_mean: t-statistic = 5.854, p-value = 0.0002425103533088105
# Significance: ***

# %% [markdown]
# ### Plot confusion matrixes

# %%
cms = model_results[(model_results['dataset'] == 'test') & (model_results['model'].isin(['GCN', 'XB']))][['model', 'TN', 'FP', 'FN', 'TP']][::-1]

# %%
cms.iloc[1][['TP', 'FP', 'FN', 'TN']].values.astype('int').reshape(2,2)
# Out:
# array([[83, 21],
#        [20, 76]])

# %%
fig = plt.figure(figsize=(5.1, 2.75))

# define colors per position: [[TP, FP], [FN, TN]]
cell_colours = [['#4CAF50', "#FF8F73EA"], 
               ["#E81E10", '#4CAF50']] 

for i in range(2):
    ax = plt.subplot(1, 2, i + 1)
    
    cm = cms.iloc[i][['TP', 'FP', 'FN', 'TN']].values.astype(int).reshape(2, 2)
    
    # blank heatmap with no color
    sns.heatmap(cm, annot=True, fmt='d', cbar=False, 
                xticklabels=['R', 'S'], yticklabels=['R', 'S'],
                linewidths=0.5, linecolor='grey', 
                annot_kws={'color': 'black', 'alpha': 0.9, 
                           'fontsize': 12
                           },
                alpha=0
                )

    # color each cell
    for row in range(2):
        for col in range(2):
            rect = Rectangle((col, row), 1, 1, fill=True, color=cell_colours[row][col], alpha=0.7)
            ax.add_patch(rect)
    if i == 0:
        # plt.xlabel('Experimental')
        plt.ylabel('Predicted')
    plt.title(cms.iloc[i]['model'])
    plt.yticks(rotation=0)

# xlabel in the middle between the two matrices
fig.text(0.54, 0.02, 'Experimental', ha='center', va='center', fontsize=12)

plt.tight_layout()
plt.show()
